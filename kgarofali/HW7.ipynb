# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
def mandel(x, y, max_iter):
    """
    Given z = x + iy and max_iter, determine whether the candidate
    is in the mandelbrot set for the given number of iterations
    """
    c = complex(x, y)
    z = 0.0j
    for i in range(max_iter):
        z = z*z + c
        if (z.real*z.real + z.imag*z.imag) >= 4:
            return i

    return max_iter

def create_fractal(Nx, Ny, xmin, xmax, ymin, ymax, max_iter):
    """Create and return a fractal image"""
    image = np.zeros((Ny, Nx), dtype=float)
    dx = (xmax - xmin) * 1. / Nx
    dy = (ymax - ymin) * 1. / Ny
    
    for x in range(Nx):
        rpart = xmin + x * dx
        for y in range(Ny):
            ipart = ymin + y * dy
            color = mandel(rpart, ipart, max_iter)
            image[y, x] = color
    return image

# %%
image = create_fractal(300, 200, -2, 1, -1, 1, 20)
plt.imshow(image, cmap=plt.cm.jet)

# %% [markdown]
# # Part 1: Using Cython

# %%
# %matplotlib inline
# %load_ext cythonmagic

# %%
# %%cython
# import numpy as np
# cimport numpy as np
# import matplotlib.pyplot as plt
# ctypedef np.float64_t dtype_t
#
# cdef float mandel_c(float x, float y, int max_iter):
#     """
#     Given z = x + iy and max_iter, determine whether the candidate
#     is in the mandelbrot set for the given number of iterations
#     """
#     cdef complex c = complex(x, y)
#     cdef complex z = 0.0j
#     cdef int i
#     for i in range(max_iter):
#         z = z*z + c
#         if (z.real*z.real + z.imag*z.imag) >= 4:
#             return i
#
#     return max_iter
#
# def create_fractal_c(int Nx, int Ny, int xmin, int xmax, int ymin, int ymax, int max_iter):
#     """Create and return a fractal image"""
#     cdef np.ndarray[dtype_t, ndim=2] image = np.zeros((Ny, Nx), dtype=float)
#     cdef float dx = (xmax - xmin) * 1. / Nx
#     cdef float dy = (ymax - ymin) * 1. / Ny
#     cdef int x
#     cdef int y
#     cdef float rpart
#     cdef float ipart
#     cdef float color
#
#     for x in range(Nx):
#         rpart = xmin + x * dx
#         for y in range(Ny):
#             ipart = ymin + y * dy
#             color = mandel_c(rpart, ipart, max_iter)
#             image[y, x] = color
#     return image

# %%
image = create_fractal_c(300, 200, -2, 1, -1, 1, 20)
plt.imshow(image, cmap=plt.cm.jet)

# %%
# %%file mandel_test.pyx
# import numpy as np
# cimport numpy as np
# from numpy cimport float_t
# ctypedef np.float64_t dtype_t
#
#
# cdef float mandel_c(float x, float y, int max_iter):
#     """
#     Given z = x + iy and max_iter, determine whether the candidate
#     is in the mandelbrot set for the given number of iterations
#     """
#     cdef complex c = complex(x, y)
#     cdef complex z = 0.0j
#     cdef int i
#     for i in range(max_iter):
#         z = z*z + c
#
#         if (z.real*z.real + z.imag*z.imag) >= 4:
#             return i
#
#     return max_iter
#
# def create_fractal_c(int Nx, int Ny, int xmin, int xmax, int ymin, int ymax, int max_iter):
#     """Create and return a fractal image"""
#     cdef np.ndarray[dtype_t,ndim=2] image = np.zeros((Ny, Nx), dtype=float)
#     cdef float dx = (xmax - xmin) * 1. / Nx
#     cdef float dy = (ymax - ymin) * 1. / Ny
#     cdef int x
#     cdef int y
#     cdef float rpart
#     cdef float ipart
#     cdef float color
#
#     for x in range(Nx):
#         rpart = xmin + x * dx
#         for y in range(Ny):
#             ipart = ymin + y * dy
#             color = mandel_c(rpart, ipart, max_iter)
#             image[y, x] = color
#     return image
# Out:
# Overwriting mandel_test.pyx

# %%
# !cython -a mandel_test.pyx

# %% [markdown]
# From the annotated HTML file it's clear that I didn't completely optimize the code with type annotations. I'm not sure what the correct way is to define the complex number "c"--apparently cython didn't like my implementation of using cdef complex. I'm also not sure why the "if" statement directly below this is not fully optimized for C. Perhaps there is a better way to use a type annotation of z.real and z.imag before the if statement? I definitely didn't use the correct type annotation for the image array. Again, I'm not sure how to get cython to treat this as a contiguous memory block rather than a python object. I tried a lot of different things to no avail.

# %% [markdown]
# # Part 2: Using Numba

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from numba import autojit

# %%
@autojit
def mandel_nb(x, y, max_iter):
    """
    Given z = x + iy and max_iter, determine whether the candidate
    is in the mandelbrot set for the given number of iterations
    """
    c = complex(x, y)
    z = 0.0j
    for i in range(max_iter):
        z = z*z + c
        if (z.real*z.real + z.imag*z.imag) >= 4:
            return i

    return max_iter

@autojit 
def create_fractal_nb(Nx, Ny, xmin, xmax, ymin, ymax, max_iter):
    """Create and return a fractal image"""
    image = np.zeros((Ny, Nx), dtype=np.float64)
    dx = (xmax - xmin) * 1. / Nx
    dy = (ymax - ymin) * 1. / Ny
    
    for x in range(Nx):
        rpart = xmin + x * dx
        for y in range(Ny):
            ipart = ymin + y * dy
            color = mandel_nb(rpart, ipart, max_iter)
            image[y, x] = color
    return image

# %%
image = create_fractal_nb(300, 200, -2, 1, -1, 1, 20)
plt.imshow(image, cmap=plt.cm.jet)

# %% [markdown]
# # Part 3: Timing Implementations

# %%
# %timeit create_fractal(300, 200, -2, 1, -1, 1, 20)
# %timeit create_fractal_c(300, 200, -2, 1, -1, 1, 20)
# %timeit create_fractal_nb(300, 200, -2, 1, -1, 1, 20)
# Out:
# 1 loops, best of 3: 343 ms per loop
# 100 loops, best of 3: 13.6 ms per loop
# 100 loops, best of 3: 2.42 ms per loop

# %% [markdown]
# # Part 4: Making a Pretty Mandelbrot Set

# %%
image = create_fractal_nb(300, 200, -1.5, -1.2, -.01, .2, 256)
plt.imshow(image, cmap=plt.cm.gist_ncar)

# %% [markdown]
# Here is my "prettiest" Mandelbrot set.
