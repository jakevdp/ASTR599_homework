# %% [markdown]
# # Russell Deitrick - HW#7 - Legacy Code and Mandlebrots

# %% [markdown]
# #### Original python program

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
def mandel(x, y, max_iter):
    """
    Given z = x + iy and max_iter, determine whether the candidate
    is in the mandelbrot set for the given number of iterations
    """
    c = complex(x, y)
    z = 0.0j
    for i in range(max_iter):
        z = z*z + c
        if (z.real*z.real + z.imag*z.imag) >= 4:
            return i

    return max_iter

def create_fractal(Nx, Ny, xmin, xmax, ymin, ymax, max_iter):
    """Create and return a fractal image"""
    image = np.zeros((Ny, Nx), dtype=float)
    dx = (xmax - xmin) * 1. / Nx
    dy = (ymax - ymin) * 1. / Ny
    
    for x in range(Nx):
        rpart = xmin + x * dx
        for y in range(Ny):
            ipart = ymin + y * dy
            color = mandel(rpart, ipart, max_iter)
            image[y, x] = color
            
    return image

# %%
image = create_fractal(300, 200, -2, 1, -1, 1, 20)
plt.imshow(image, cmap=plt.cm.jet)

# %% [markdown]
# #### Part 1) Making it faster!

# %%
# %load_ext cythonmagic

# %%
# %%file mand_cy.pyx
# import numpy as np
# from numpy cimport float_t, complex128_t
#
# cdef int mandel_cy(float_t x, float_t y, int max_iter):
#     """
#     Given z = x + iy and max_iter, determine whether the candidate
#     is in the mandelbrot set for the given number of iterations
#     """
#     cdef complex128_t c = np.complex(x, y)
#     cdef complex128_t z = 0.0j
#     cdef int i
#     for i in range(max_iter):
#         z = z*z + c
#         if (z.real*z.real + z.imag*z.imag) >= 4:
#             return i
#
#     return max_iter
#
# cdef float_t[:,:] create_fractal_cy(int Nx, int Ny, int xmin, int xmax, int ymin, int ymax, int max_iter):
#     """Create and return a fractal image"""
#     cdef float_t[:,:] image = np.zeros((Ny, Nx), dtype=np.float64)
#     cdef float_t dx = (xmax - xmin) * 1. / Nx
#     cdef float_t dy = (ymax - ymin) * 1. / Ny
#     cdef float_t rpart, ipart
#     cdef int color
#     cdef int x, y
#
#     for x in range(Nx):
#         rpart = xmin + x * dx
#         for y in range(Ny):
#             ipart = ymin + y * dy
#             color = mandel_cy(rpart, ipart, max_iter)
#             image[y, x] = color
#     return image
# Out:
# Overwriting mand_cy.pyx

# %%
# !cython -a mand_cy.pyx

# %%
# %%cython
# import numpy as np
# from numpy cimport float_t, complex128_t
#
# cdef int mandel_cy(float_t x, float_t y, int max_iter):
#     """
#     Given z = x + iy and max_iter, determine whether the candidate
#     is in the mandelbrot set for the given number of iterations
#     """
#     cdef complex128_t c = complex(x, y)
#     cdef complex128_t z = 0.0j
#     cdef int i
#     for i in range(max_iter):
#         z = z*z + c
#         if (z.real*z.real + z.imag*z.imag) >= 4:
#             return i
#
#     return max_iter
#
# cdef float_t[:,:] create_fractal_cy(int Nx, int Ny, int xmin, int xmax, int ymin, int ymax, int max_iter):
#     """Create and return a fractal image"""
#     cdef float_t[:,:] image = np.zeros((Ny, Nx), dtype=float)
#     cdef float_t dx = (xmax - xmin) * 1. / Nx
#     cdef float_t dy = (ymax - ymin) * 1. / Ny
#     cdef float_t rpart, ipart
#     cdef int color
#     cdef int x, y
#
#     for x in range(Nx):
#         rpart = xmin + x * dx
#         for y in range(Ny):
#             ipart = ymin + y * dy
#             color = mandel_cy(rpart, ipart, max_iter)
#             image[y, x] = color
#     return image

# %% [markdown]
# #### Part 2) Numba

# %%
from numba import autojit
mandel_nb = autojit(mandel)

# %% [raw]
# Rewriting create_fractal to use mandel_nb.

# %%
def create_fractal0(Nx, Ny, xmin, xmax, ymin, ymax, max_iter):
    """Create and return a fractal image"""
    image = np.zeros((Ny, Nx), dtype=np.float64)
    dx = (xmax - xmin) * 1. / Nx
    dy = (ymax - ymin) * 1. / Ny
    
    for x in range(Nx):
        rpart = xmin + x * dx
        for y in range(Ny):
            ipart = ymin + y * dy
            color = mandel_nb(rpart, ipart, max_iter)
            image[y, x] = color
            
    return image

# %%
create_fractal_nb = autojit(create_fractal0)

# %% [markdown]
# #### Part 3) Time it!

# %%
# %timeit create_fractal(300, 200, -2, 1, -1, 1, 20)
# %timeit create_fractal_cy(300, 200, -2, 1, -1, 1, 20)
# %timeit create_fractal_nb(300, 200, -2, 1, -1, 1, 20)
# Out:
# 1 loops, best of 3: 259 ms per loop
# 10 loops, best of 3: 181 ms per loop
# 1000 loops, best of 3: 1.95 ms per loop

# %% [raw]
# I'm not sure why I can't get Cython to make this faster.  Grr...  Numba works pretty well though.

# %% [markdown]
# #### Part 4) Pretty picture

# %%
image = create_fractal_nb(7000, 7000, -2, 1, -1, 1, 256)
plt.imshow(image, cmap=plt.cm.gist_earth, extent=[-2,1,-1,1])
plt.xlim(-0.05,0.05)
plt.ylim(0.75,0.85)
# Out:
# (0.75, 0.85)

# %% [raw]
# I like this color map.
