# %%
#HW 3
#Eddie Schwieterman
#If we do not get through this whole exercise, your homework will be to finish the notebook, 
#and then repeat the analysis for another variable star from the data. I would like to see as a
#function of the number of terms in your analysis: χ2, Δχ2 compared to the previous model, the
#significance of Δχ2, AIC, and BIC. Indicate the order of the series you would choose based
#on each of the above numbers (they may be different for Δχ2, AIC, and BIC).

# %%
#note book was finished in class - will repeat exercise for a different variable star (LINEAR 10022663) 
#(Saw this one on the AstroML documentation)

# %%
# %matplotlib inline
import astroML.datasets
import numpy as np
import matplotlib.pyplot as plt

# %%
lcs = astroML.datasets.fetch_LINEAR_sample()
print lcs
# Out:
# <astroML.datasets.LINEAR_sample.LINEARdata instance at 0x10a13c248>

# %%
#This is another variable star from the LINEAR data set
#Saw it here: http://www.astroml.org/user_guide/datasets.html
time, flux, dflux = lcs[10022663].T

# %%
#plot raw lightcurve with errors
plt.errorbar(time, flux, yerr=dflux, fmt="ro")
plt.gca().invert_yaxis()
plt.xlabel("MJD")
plt.ylabel("Mag")
plt.show()

# %%
#import the Lomb Scargle routine from AstroML, then plot the periodogram
from astroML.time_series import lomb_scargle
periods = np.logspace(-2, 0, 10000, base=10)
periodogram = lomb_scargle(time, flux, dflux, omega=2 * np.pi / periods, generalized=True)
#omega=phase in radians

# %%
#plot periodogram
plt.plot(periods, periodogram)
plt.semilogx()
plt.xlabel("Period (days)")
plt.ylabel("Power")
plt.show()

# %%
#now we can find the peak using argsort - periodogram definitely looks different than that for LINEAR 18525697
idx = np.argsort(periodogram)
print periods[idx[-1]], periodogram[idx[-1]]
# Out:
# 0.275768117463 0.604428223521

# %%
#fold the light curve and print the min & max phase points
period = periods[idx[-1]]
phase = time / period - time // period 
print min(phase), max(phase)
# Out:
# 0.00607246582513 0.999633340572

# %%
#plot the folded light curve
plt.errorbar(phase, flux, yerr=dflux, fmt="ro")
plt.gca().invert_yaxis()
plt.xlabel("Phase")
plt.ylabel("Mag")
plt.show()

# %%
#We are going to use the following model again:
#Model = A0 + A1 cos(2 π phase + ϕ1) + A2 cos(2 π 2 ⋅ phase + ϕ2) + ... + AN * cos(2 π N ⋅ phase + ϕN)
#..with model parameters [ A0 A1 ϕ1 A2 ϕ2 ... AN ϕN ]

# %%
#define a class that will contain a method to return a lightcurve given phase variables and a set of terms
#from Andy's notebook...
class Fourier(object):
    def __init__(self, phase, flux, dflux, nterms):
        self.phase = phase
        self.flux = flux
        self.dflux = dflux
        self.nterms = nterms
        assert(self.nterms > 0)
        
    def evaluate(self, phase, terms):
        assert(len(terms) == 2 * self.nterms - 1)
        model = terms[0] * np.ones(len(phase))
        for i in range(self.nterms-1):
            model += terms[2*i + 1] * np.cos(2 * np.pi * (i+1) * phase + terms[2*i + 2])
        return model
    
    def chi2(self, args):
        model = self.evaluate(self.phase, args)
        chi   = (model - self.flux) / self.dflux
        return np.sum(chi**2)

# %%
#create an instance of this class
fourier = Fourier(phase, flux, dflux, 2)
mphase = np.arange(0, 1, 0.01)
model = fourier.evaluate(mphase, [10, 0.1, 0.0])

# %%
#plot it
plt.plot(mphase, model, "k-")
plt.gca().invert_yaxis()
plt.xlabel("Phase")
plt.ylabel("Model mag")
plt.show()

# %%
#import the scipy optimize routine so we can minimize chi2 and find the best model parameters
import scipy.optimize as opt

# %%
#Fit a 2 term model to the data (1 constant term, and 1 term with an amplitude and phase offset)
fourier = Fourier(phase, flux, dflux, 2)
guess   = []
guess.append(np.mean(fourier.flux)) #amplitude guess
guess.append(np.std(fourier.flux))  #phase offset guess

# %%
#find the phase of minimum flux
print np.argsort(fourier.flux)[-1] #index containing the minimum flux
# Out:
# 187

# %%
#minimum flux is
print fourier.flux[187]
# Out:
# 14.665

# %%
#phase with minimum flux is then
print fourier.phase[187]
# Out:
# 0.0368947045645

# %%
#looks good
guess.append(2 * np.pi * (1 - fourier.phase[187]))

# %%
#now let's optimize
opt.fmin_bfgs(fourier.chi2, x0=[guess], disp=0, full_output=1)
# Out:
# (array([ 14.22828703,   0.2559701 ,   7.49868203]),
#  49281.830240076437,
#  array([ 0.00195312,  0.0078125 ,  0.00048828]),
#  array([[  2.06593849e-07,  -3.70068307e-07,  -5.18607477e-07],
#        [ -3.70068307e-07,   2.07953611e-06,   9.49254373e-08],
#        [ -5.18607477e-07,   9.49254373e-08,   2.97741115e-06]]),
#  304,
#  58,
#  2)

# %%
#look at the best fit parameters
result = opt.fmin_bfgs(fourier.chi2, x0=[guess], disp=0, full_output=1)
best_fit = result[0]
print best_fit
# Out:
# [ 14.22828703   0.2559701    7.49868203]

# %%
#compare the model to the data and initial guess
plt.errorbar(fourier.phase, fourier.flux, yerr=fourier.dflux, fmt="ro")
plt.plot(mphase, fourier.evaluate(mphase, guess), "b--", label="Initial guess")
plt.plot(mphase, fourier.evaluate(mphase, best_fit), "g-", label="Best fit")
plt.gca().invert_yaxis()
plt.xlabel("Phase")
plt.ylabel("Mag")
plt.legend()
plt.show()

# %%
#doesn't look that great
#The goodness of fit/reduced chi2 is
chi2 = fourier.chi2(best_fit)
print chi2, chi2 / (len(flux) - len(best_fit) - 1)
# Out:
# 49281.8302401 203.643926612

# %%
#pretty bad, obviously we need more terms.

# %%
#add more terms to model
fourier2 = Fourier(phase, flux, dflux, 3)
guess2   = [] # this needs to be the number of paramters you want to fit for, now 2*3-1 = 5
guess2.append(np.mean(fourier2.flux))
guess2.append(np.std(fourier2.flux))
guess2.append(2 * np.pi * (1 - fourier2.phase[np.argsort(fourier2.flux)[-1]]))
guess2.append(0.0)
guess2.append(2 * np.pi * (1 - fourier2.phase[np.argsort(fourier2.flux)[-1]]))
result2 = opt.fmin_bfgs(fourier2.chi2, x0=[guess2], disp=0, full_output=1)
best_fit2 = result2[0]
print best_fit2
# Out:
# [ 14.22915046   0.23965505   7.39337979   0.1134598    6.56010364]

# %%
#plot 5 parameter model
plt.errorbar(fourier2.phase, fourier2.flux, yerr=fourier2.dflux, fmt="ro")
plt.plot(mphase, fourier2.evaluate(mphase, guess2), "b--", label="Initial guess")
plt.plot(mphase, fourier2.evaluate(mphase, best_fit2), "g-", label="Best fit")
plt.gca().invert_yaxis()
plt.xlabel("Phase")
plt.ylabel("Mag")
plt.show()

# %%
#doesn't do so well near 0 phase. Does adding even more terms help?

# %%
#9 parameter fit
fourier5 = Fourier(phase, flux, dflux, 5)
guess5   = [] # this needs to be the number of paramters you want to fit for, now 9
guess5.append(np.mean(fourier5.flux))
guess5.append(np.std(fourier5.flux))
guess5.append(2 * np.pi * (1 - fourier5.phase[np.argsort(fourier5.flux)[-1]]))
for i in range(2, 5):
    guess5.append(0.0)
    guess5.append(2 * np.pi * (1 - fourier5.phase[np.argsort(fourier5.flux)[-1]]))
result5 = opt.fmin_bfgs(fourier5.chi2, x0=[guess5], disp=0, full_output=1)
best_fit5 = result5[0]
print best_fit5
# Out:
# [ 14.236225     0.23740794   7.36623455   0.10915846   6.43970755
#    0.06213519   5.72790136   0.03967364   5.24147578]

# %%
#plot 9 parameter model
plt.errorbar(fourier5.phase, fourier5.flux, yerr=fourier5.dflux, fmt="ro")
plt.plot(mphase, fourier5.evaluate(mphase, guess5), "b--", label="Initial guess")
plt.plot(mphase, fourier5.evaluate(mphase, best_fit5), "g-", label="Best fit")
plt.gca().invert_yaxis()
plt.xlabel("Phase")
plt.ylabel("Mag")
plt.show()

# %%
#not too bad!

# %%
#make a method on the class that initiates the guess for us so we don't have to append all that stuff.
class Fourier2(Fourier):
    def __init__(self, phase, flux, dflux, nterms):
        Fourier.__init__(self, phase, flux, dflux, nterms)
                
    def makeGuess(self):
        guess = []
        guess.append(np.mean(self.flux))
        if self.nterms > 1:
            guess.append(np.std(self.flux))
            guess.append(2 * np.pi * (1 - self.phase[np.argsort(self.flux)[-1]]))
            for i in range(2, self.nterms):
                guess.append(0.0)
                guess.append(2 * np.pi * (1 - self.phase[np.argsort(self.flux)[-1]]))
        return guess

# %%
#test chi2 as a function of the number of paramters in our model
nterms = np.arange(1, 10)
chi2   = []
for nterm in nterms:
    fourier = Fourier2(phase, flux, dflux, nterm)
    guess   = fourier.makeGuess()
    print guess
    chi2.append(opt.fmin_bfgs(fourier.chi2, x0=[guess], disp=0, full_output=1)[1])
chi2 = np.array(chi2)
plt.plot(nterms, chi2)
plt.xlabel("N Terms")
plt.ylabel("Chi2")
plt.show()
# Out:
# [14.253743902439028]
# [14.253743902439028, 0.22742531040412647, 6.051369041547348]
# [14.253743902439028, 0.22742531040412647, 6.051369041547348, 0.0, 6.051369041547348]
# [14.253743902439028, 0.22742531040412647, 6.051369041547348, 0.0, 6.051369041547348, 0.0, 6.051369041547348]
# [14.253743902439028, 0.22742531040412647, 6.051369041547348, 0.0, 6.051369041547348, 0.0, 6.051369041547348, 0.0, 6.051369041547348]
# [14.253743902439028, 0.22742531040412647, 6.051369041547348, 0.0, 6.051369041547348, 0.0, 6.051369041547348, 0.0, 6.051369041547348, 0.0, 6.051369041547348]
# [14.253743902439028, 0.22742531040412647, 6.051369041547348, 0.0, 6.051369041547348, 0.0, 6.051369041547348, 0.0, 6.051369041547348, 0.0, 6.051369041547348, 0.0, 6.051369041547348]
# [14.253743902439028, 0.22742531040412647, 6.051369041547348, 0.0, 6.051369041547348, 0.0, 6.051369041547348, 0.0, 6.051369041547348, 0.0, 6.051369041547348, 0.0, 6.051369041547348, 0.0, 6.051369041547348]
# [14.253743902439028, 0.22742531040412647, 6.051369041547348, 0.0, 6.051369041547348, 0.0, 6.051369041547348, 0.0, 6.051369041547348, 0.0, 6.051369041547348, 0.0, 6.051369041547348, 0.0, 6.051369041547348, 0.0, 6.051369041547348]

# %%
# on first glance we don't get much better after Nterms=5

# %%
#let's take a gander at the delta chi2
delta_chi2 = chi2[:-1] - chi2[1:]
plt.plot(nterms[1:], delta_chi2)
plt.xlabel("N terms")
plt.ylabel("Delta chi2")
plt.show()

# %%
#looks like Nterms=6 is as far as we should go.

# %%
#Andy: Lets start to look at the penalties imposed by BIC/AIC.
#BIC: Bayesian information criterion
#AIC: Akaike information criterion

# %%
nterms     = np.arange(1, 10)
chi2       = []
BICpenalty = []
AICpenalty = []
for nterm in nterms:
    fourier = Fourier2(phase, flux, dflux, nterm)
    guess   = fourier.makeGuess()
    BICpenalty.append(len(guess) * np.log(len(fourier.phase)))
    AICpenalty.append(len(guess) * 2.0)
    chi2.append(opt.fmin_bfgs(fourier.chi2, x0=[guess], disp=0, full_output=1)[1])
chi2 = np.array(chi2)
BICpenalty = np.array(BICpenalty)
AICpenalty = np.array(AICpenalty)

# %%
#check them out!
print chi2
print BICpenalty
print AICpenalty
# Out:
# [ 124583.78774732   49281.83024008   33742.32691986   29395.54032816
#    27506.63792852   27394.09859154   27338.85276239   27209.60808483
#    27055.69077426]
# [  5.50533154  16.51599461  27.52665768  38.53732075  49.54798382
#   60.5586469   71.56930997  82.57997304  93.59063611]
# [  2.   6.  10.  14.  18.  22.  26.  30.  34.]

# %%
plt.plot(nterms, chi2, label="chi2")
plt.plot(nterms, chi2 + BICpenalty, label="BIC")
plt.plot(nterms, chi2 + AICpenalty, label="AIC")
plt.xlabel("N Terms")
plt.ylabel("Chi2")
plt.semilogy()
plt.legend()
plt.show()

# %%
#it doesn't look like these are diverging at all...
#what happens when we add even more parameters?
nterms     = np.arange(1, 30, 2)
chi2       = []
BICpenalty = []
AICpenalty = []
for nterm in nterms:
    fourier = Fourier2(phase, flux, dflux, nterm)
    guess   = fourier.makeGuess()
    BICpenalty.append(len(guess) * np.log(len(fourier.phase)))
    AICpenalty.append(len(guess) * 2.0)
    chi2.append(opt.fmin_bfgs(fourier.chi2, x0=[guess], disp=0, full_output=1)[1])
chi2 = np.array(chi2)
BICpenalty = np.array(BICpenalty)
AICpenalty = np.array(AICpenalty)

# %%
plt.plot(nterms, chi2, label="chi2")
plt.plot(nterms, chi2 + BICpenalty, label="BIC")
plt.plot(nterms, chi2 + AICpenalty, label="AIC")
plt.xlabel("N Terms")
plt.ylabel("Chi2")
plt.semilogy()
plt.legend()
plt.show()

# %%
#there's no apparent difference between the penaltized and unpenalized sets.
#Which of the fits have the minimum BIC/AIC and what order model do they suggest?
print np.argsort(chi2+BICpenalty)[0],np.argsort(chi2+AICpenalty)[0]
# Out:
# 14 14

# %%
print nterms[4], nterms[6]
# Out:
# 9 13

# %%
#it looks like you'd want to choose a model of order 9-13. 
#From the delta chi2 plot above I would assume that N=6 terms would be the maximum worth doing.
