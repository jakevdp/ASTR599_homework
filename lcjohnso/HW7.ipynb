# %% [markdown]
# # HW7: Extending Python

# %% [markdown]
# Cliff Johnson
#
# Note: After hours of trying, I was unable to get Numba installed into my Enthought Python distribution.  In the end, I downloaded Anaconda for this single assignment.  Complex (and sometimes impossible) package installation procedures has always been my gripe about Python.  While bundled distributions seem to help, if multiple bundles are required to obtain all the best tools, that seems to defeat the purpose.

# %% [markdown]
# Mandelbrot Set Homework

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
def mandel(x, y, max_iter):
    """
    Given z = x + iy and max_iter, determine whether the candidate
    is in the mandelbrot set for the given number of iterations
    """
    c = complex(x, y)
    z = 0.0j
    for i in range(max_iter):
        z = z*z + c
        if (z.real*z.real + z.imag*z.imag) >= 4:
            return i

    return max_iter

def create_fractal(Nx, Ny, xmin, xmax, ymin, ymax, max_iter):
    """Create and return a fractal image"""
    image = np.zeros((Ny, Nx), dtype=float)
    dx = (xmax - xmin) * 1. / Nx
    dy = (ymax - ymin) * 1. / Ny
    
    for x in range(Nx):
        rpart = xmin + x * dx
        for y in range(Ny):
            ipart = ymin + y * dy
            color = mandel(rpart, ipart, max_iter)
            image[y, x] = color
    return image

# %%
image = create_fractal(300, 200, -2, 1, -1, 1, 20)
plt.imshow(image, cmap=plt.cm.jet)

# %% [markdown]
# Part 1: Use Cython to speed up code

# %%
# %%cython
# import numpy as np
#
# def mandel_c(x, y, max_iter):
#     """
#     Given z = x + iy and max_iter, determine whether the candidate
#     is in the mandelbrot set for the given number of iterations
#     """
#     c = complex(x, y)
#     z = 0.0j
#     for i in range(max_iter):
#         z = z*z + c
#         if (z.real*z.real + z.imag*z.imag) >= 4:
#             return i
#
#     return max_iter
#
# def create_fractal_c(Nx, Ny, xmin, xmax, ymin, ymax, max_iter):
#     """Create and return a fractal image"""
#     image = np.zeros((Ny, Nx), dtype=float)
#     dx = (xmax - xmin) * 1. / Nx
#     dy = (ymax - ymin) * 1. / Ny
#
#     for x in range(Nx):
#         rpart = xmin + x * dx
#         for y in range(Ny):
#             ipart = ymin + y * dy
#             color = mandel_c(rpart, ipart, max_iter)
#             image[y, x] = color
#     return image

# %%
# %%cython
# import numpy as np
# cimport numpy as np
#
# def mandel_c2(float x, float y, int max_iter):
#     """
#     Given z = x + iy and max_iter, determine whether the candidate
#     is in the mandelbrot set for the given number of iterations
#     """
#     cdef complex c = complex(x, y)
#     cdef complex z = 0.0j
#     cdef int i
#     for i in range(max_iter):
#         z = z*z + c
#         if (z.real*z.real + z.imag*z.imag) >= 4:
#             return i
#
#     return max_iter
#
# def create_fractal_c2(int Nx, int Ny, int xmin, int xmax, int ymin, int ymax, int max_iter):
#     """Create and return a fractal image"""
#     cdef np.ndarray image = np.zeros((Ny, Nx), dtype=int)
#     cdef float dx = (xmax - xmin) * 1. / Nx
#     cdef float dy = (ymax - ymin) * 1. / Ny
#
#     cdef int x
#     cdef int y
#     cdef float rpart
#     cdef float ipart
#     cdef int color
#     for x in range(Nx):
#         rpart = xmin + x * dx
#         for y in range(Ny):
#             ipart = ymin + y * dy
#             color = mandel_c2(rpart, ipart, max_iter)
#             image[y, x] = color
#     return image

# %%
# Test
image = create_fractal_c(300, 200, -2, 1, -1, 1, 256)
plt.imshow(image, cmap=plt.cm.jet)
print np.min(image)
print np.max(image)
# Out:
# 0.0
# 256.0

# %%
# %%file create_fractal.pyx
# import numpy as np
# cimport numpy as np
#
# def mandel_c2(float x, float y, int max_iter):
#     """
#     Given z = x + iy and max_iter, determine whether the candidate
#     is in the mandelbrot set for the given number of iterations
#     """
#     cdef complex c = complex(x, y)
#     cdef complex z = 0.0j
#     cdef int i
#     for i in range(max_iter):
#         z = z*z + c
#         if (z.real*z.real + z.imag*z.imag) >= 4:
#             return i
#
#     return max_iter
#
# def create_fractal_c2(int Nx, int Ny, int xmin, int xmax, int ymin, int ymax, int max_iter):
#     """Create and return a fractal image"""
#     cdef np.ndarray image = np.zeros((Ny, Nx), dtype=int)
#     cdef float dx = (xmax - xmin) * 1. / Nx
#     cdef float dy = (ymax - ymin) * 1. / Ny
#
#     cdef int x
#     cdef int y
#     cdef float rpart
#     cdef float ipart
#     cdef int color
#     for x in range(Nx):
#         rpart = xmin + x * dx
#         for y in range(Ny):
#             ipart = ymin + y * dy
#             color = mandel_c2(rpart, ipart, max_iter)
#             image[y, x] = color
#     return image
# Out:
# Overwriting create_fractal.pyx

# %%
# !cython -a create_fractal.pyx

# %% [markdown]
# Part 2: Use Numba to speed up code

# %%
from numba import autojit

@autojit
def mandel_n(x, y, max_iter):
    """
    Given z = x + iy and max_iter, determine whether the candidate
    is in the mandelbrot set for the given number of iterations
    """
    c = complex(x, y)
    z = 0.0j
    for i in range(max_iter):
        z = z*z + c
        if (z.real*z.real + z.imag*z.imag) >= 4:
            return i

    return max_iter

@autojit
def create_fractal_n(Nx, Ny, xmin, xmax, ymin, ymax, max_iter):
    """Create and return a fractal image"""
    image = np.zeros((Ny, Nx), dtype=float)
    dx = (xmax - xmin) * 1. / Nx
    dy = (ymax - ymin) * 1. / Ny
    
    for x in range(Nx):
        rpart = xmin + x * dx
        for y in range(Ny):
            ipart = ymin + y * dy
            color = mandel_n(rpart, ipart, max_iter)
            image[y, x] = color
    return image

# %% [markdown]
# Part 3: Compare runtimes for three versions of code

# %%
print "Python:"
# %timeit create_fractal(300, 200, -2, 1, -1, 1, 20)
print "Raw Cython:"
# %timeit create_fractal_c(300, 200, -2, 1, -1, 1, 20)
print "Improved Cython:"
# %timeit create_fractal_c2(300, 200, -2, 1, -1, 1, 20)
print "Numba:"
# %timeit create_fractal_n(300, 200, -2, 1, -1, 1, 20)
# Out:
# Python:
# 1 loops, best of 3: 396 ms per loop
# Raw Cython:
# 1 loops, best of 3: 222 ms per loop
# Improved Cython:
# 10 loops, best of 3: 29.4 ms per loop
# Numba:
# 1 loops, best of 3: 2.91 ms per loop

# %% [markdown]
# Part 4: Make beautiful visualization of the Mandelbrot set

# %%
image = create_fractal_n(6000, 4000, -2, 1, -1, 1, 100)

# %%
plt.imshow(image, cmap=plt.cm.spectral_r)
plt.xlim(2500,2650)
plt.ylim(1375,1550)
# Out:
# (1375, 1550)
