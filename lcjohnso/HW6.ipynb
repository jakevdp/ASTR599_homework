# %% [markdown]
# # HW6: scikit-learn

# %% [markdown]
# Cliff Johnson

# %%
import numpy as np
# %pylab inline
from sklearn import preprocessing
from sklearn.metrics import classification_report
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Part 1: RR Lyrae Exercise

# %%
from astroML.datasets import fetch_rrlyrae_combined
from sklearn.cross_validation import train_test_split

X, y = fetch_rrlyrae_combined()

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
N_plot = 5000
plt.scatter(X[-N_plot:, 0], X[-N_plot:, 1], c=y[-N_plot:],
            edgecolors='none')
plt.xlabel('u-g color')
plt.ylabel('g-r color')

snames=['Other','RR Lyrae']
formatter = plt.FuncFormatter(lambda i, *args: snames[int(i)])
plt.colorbar(ticks=[0, 1], format=formatter)
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x10d6a3e60>

# %%
from sklearn.neighbors import KNeighborsClassifier
clf = KNeighborsClassifier(n_neighbors=5)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
print classification_report(y_test, y_pred,
                            target_names=['MS star', 'RR Lyrae'])
# Out:
#              precision    recall  f1-score   support
#
#     MS star       1.00      1.00      1.00     23157
#    RR Lyrae       0.70      0.58      0.64       129
#
# avg / total       1.00      1.00      1.00     23286

# %% [markdown]
# ### Exercise 1: Classification of RR Lyrae
#
# Use another classifier and try to improve on this precision/recall score.
#
# There are several you might try:
#
# - ``sklearn.neighbors.GaussianNaiveBayes`` (slow but inaccurate)
# - ``sklearn.lda.LDA`` (slow but inaccurate)
# - ``sklearn.svm.SVC`` (fast but accurate)
# - ``sklearn.svm.SVC`` with ``kernel='rbf'`` (fast but accurate)
# - ``sklearn.ensemble.RandomForestClassifier`` (fast & potentially accurate with tuning)
#
# For the slower algorithms, it might be a good idea to use only part of the dataset as you experiment, i.e. when training do something like the following:
#
# ```
# clf.fit(X_train[::5], y_train[::5])
# ```
#
# Once you're happy, you can run the training on the full dataset.
#
# What's the best precision/recall you can obtain for the RR-Lyrae data?

# %%
from sklearn.svm import SVC

X_scaled = preprocessing.scale(X)
Xs_train, Xs_test, ys_train, ys_test = train_test_split(X_scaled, y)

clf = SVC(class_weight={0:1,1:15},cache_size=1000)
clf.fit(Xs_train, ys_train)
ys_pred = clf.predict(Xs_test)
print classification_report(ys_test, ys_pred,
                            target_names=['MS star', 'RR Lyrae'])
# Out:
#              precision    recall  f1-score   support
#
#     MS star       1.00      0.99      1.00     23158
#    RR Lyrae       0.37      0.88      0.52       128
#
# avg / total       1.00      0.99      0.99     23286

# %%
from sklearn.svm import LinearSVC
clf = LinearSVC()
clf.fit(Xs_train, ys_train)
y_pred = clf.predict(Xs_test)
print classification_report(ys_test, ys_pred,
                            target_names=['MS star', 'RR Lyrae'])
# Out:
#              precision    recall  f1-score   support
#
#     MS star       1.00      0.99      1.00     23158
#    RR Lyrae       0.37      0.88      0.52       128
#
# avg / total       1.00      0.99      0.99     23286

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators=12,criterion="entropy")
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print classification_report(y_test, y_pred,
                            target_names=['MS star', 'RR Lyrae'])
# Out:
#              precision    recall  f1-score   support
#
#     MS star       1.00      1.00      1.00     23157
#    RR Lyrae       0.79      0.53      0.64       129
#
# avg / total       1.00      1.00      1.00     23286

# %%
clf = KNeighborsClassifier(n_neighbors=7)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print classification_report(y_test, y_pred,
                            target_names=['MS star', 'RR Lyrae'])
# Out:
#              precision    recall  f1-score   support
#
#     MS star       1.00      1.00      1.00     23157
#    RR Lyrae       0.74      0.60      0.66       129
#
# avg / total       1.00      1.00      1.00     23286

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(criterion='entropy')
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print classification_report(y_test, y_pred,
                            target_names=['MS star', 'RR Lyrae'])
# Out:
#              precision    recall  f1-score   support
#
#     MS star       1.00      1.00      1.00     23157
#    RR Lyrae       0.62      0.53      0.57       129
#
# avg / total       1.00      1.00      1.00     23286

# %% [markdown]
# Exercise 1 Result:
#
# I was unable to reach high combined precision and recall using any of the following techniques: decision tree classifier, nearest neighbors (k=7), random forest, and SVC (both normal and linear).  One hint I learned: SVC results were improved once I scaled the inputs.

# %% [markdown]
# ### Part 2: SDSS Galaxy Spectra

# %%
from astroML.datasets import fetch_sdss_specgals
data = fetch_sdss_specgals()

# put magnitudes in a matrix
X = np.vstack([data['modelMag_%s' % f] for f in 'ugriz']).T
y = data['z']

# Split into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
print data.dtype.names
# Out:
# ('ra', 'dec', 'mjd', 'plate', 'fiberID', 'z', 'zErr', 'rChi2', 'velDisp', 'velDispErr', 'extinction_r', 'petroMag_r', 'psfMag_r', 'psfMagErr_r', 'modelMag_u', 'modelMagErr_u', 'modelMag_g', 'modelMagErr_g', 'modelMag_r', 'modelMagErr_r', 'modelMag_i', 'modelMagErr_i', 'modelMag_z', 'modelMagErr_z', 'petroR50_r', 'petroR90_r', 'nii_6584_flux', 'nii_6584_flux_err', 'h_alpha_flux', 'h_alpha_flux_err', 'oiii_5007_flux', 'oiii_5007_flux_err', 'h_beta_flux', 'h_beta_flux_err', 'h_delta_flux', 'h_delta_flux_err', 'd4000', 'd4000_err', 'bptclass', 'lgm_tot_p50', 'sfr_tot_p50', 'objID', 'specObjID')

# %%
from sklearn.linear_model import LinearRegression
est = LinearRegression()
est.fit(X_train, y_train)
y_pred = est.predict(X_test)

plt.plot(y_test, y_pred, ',k')
plt.plot([0, 1], [0, 1], ':k')
plt.xlim([0, 0.6])
plt.ylim([0, 0.6])

rms = np.sqrt(np.mean((y_test - y_pred) ** 2))
print rms
# Out:
# 0.0325851432734

# %% [markdown]
# ### Exercise 2
#
# Try to improve on this result using another regression algorithm.  Some potential choices:
#
# - ``sklearn.neighbors.KNeighborsRegressor`` (fast-ish, but often inaccurate
# - ``sklearn.svm.SVR`` (potentially accurate, but slow)
# - ``sklearn.ensemble.RandomForestRegressor`` (fast, and accurate with tuning)
# - ``sklearn.ensemble.GradientBoostingRegressor`` (accurate with tuning, can be very slow depending on parameters)
#
# Again, sub-sampling the data can help as you explore some of the slower techniques.

# %%
from sklearn.neighbors import KNeighborsRegressor
est = KNeighborsRegressor()
est.fit(X_train, y_train)
y_pred = est.predict(X_test)

plt.plot(y_test, y_pred, ',k')
plt.plot([0, 1], [0, 1], ':k')
plt.xlim([0, 0.6])
plt.ylim([0, 0.6])

rms = np.sqrt(np.mean((y_test - y_pred) ** 2))
print rms
# Out:
# 0.0233114131705

# %%
from sklearn.ensemble import RandomForestRegressor
est = RandomForestRegressor()
est.fit(X_train, y_train)
y_pred = est.predict(X_test)

plt.plot(y_test, y_pred, ',k')
plt.plot([0, 1], [0, 1], ':k')
plt.xlim([0, 0.6])
plt.ylim([0, 0.6])

rms = np.sqrt(np.mean((y_test - y_pred) ** 2))
print rms
# Out:
# 0.0229583176722

# %%
#TAKES FOREVER
from sklearn.svm import SVR
est = SVR()

est.fit(X_train, y_train)
ys_pred = est.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-e3477451e8e8> in <module>()
#      11 plt.ylim([0, 0.6])
#      12
# ---> 13 rms = np.sqrt(np.mean((ys_test - ys_pred) ** 2))
#      14 print rms
#
# ValueError: operands could not be broadcast together with shapes (23286) (165400)

# %%
plt.plot(y_test, y_pred, ',k')
plt.plot([0, 1], [0, 1], ':k')
plt.xlim([0, 0.6])
plt.ylim([0, 0.6])

rms = np.sqrt(np.mean((ys_test - ys_pred) ** 2))
print rms
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-5d08e63ae447> in <module>()
#       4 plt.ylim([0, 0.6])
#       5
# ----> 6 rms = np.sqrt(np.mean((ys_test - ys_pred) ** 2))
#       7 print rms
#
# ValueError: operands could not be broadcast together with shapes (23286) (165400)

# %% [markdown]
# Exercise 2 Result:
#
# SVR took too long and did not yield better results - not worth it.  Both the KNeighborsRegressor and the RandomForestRegressor worked well, providing residuals with a RMS of < 0.03 and plotted relations that looked acceptable.
