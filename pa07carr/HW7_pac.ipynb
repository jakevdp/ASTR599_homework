# %% [markdown]
# Patti Carroll
#
# HW7

# %%
#%matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

def mandel(x, y, max_iter):
    """
    Given z = x + iy and max_iter, determine whether the candidate
    is in the mandelbrot set for the given number of iterations
    """
    c = complex(x, y)
    z = 0.0j
    for i in range(max_iter):
        z = z*z + c
        if (z.real*z.real + z.imag*z.imag) >= 4:
            return i

    return max_iter

def create_fractal(Nx, Ny, xmin, xmax, ymin, ymax, max_iter):
    """Create and return a fractal image"""
    image = np.zeros((Ny, Nx), dtype=float)
    dx = (xmax - xmin) * 1. / Nx
    dy = (ymax - ymin) * 1. / Ny
    
    for x in range(Nx):
        rpart = xmin + x * dx
        for y in range(Ny):
            ipart = ymin + y * dy
            color = mandel(rpart, ipart, max_iter)
            image[y, x] = color
    return image

# %%
image = create_fractal(300, 200, -2, 1, -1, 1, 20)
plt.imshow(image, cmap=plt.cm.jet)

# %%
print "Python only:"
# %timeit create_fractal(300, 200, -2, 1, -1, 1, 20)
# Out:
# Python only:
# 1 loops, best of 3: 401 ms per loop

# %%
# %load_ext cythonmagic

# %%
# %%cython
# #%matplotlib inline
# import numpy as np
# import matplotlib.pyplot as plt
#
# def mandel(x, y, max_iter):
#     """
#     Given z = x + iy and max_iter, determine whether the candidate
#     is in the mandelbrot set for the given number of iterations
#     """
#     c = complex(x, y)
#     z = 0.0j
#     for i in range(max_iter):
#         z = z*z + c
#         if (z.real*z.real + z.imag*z.imag) >= 4:
#             return i
#
#     return max_iter
#
# def create_fractal(Nx, Ny, xmin, xmax, ymin, ymax, max_iter):
#     """Create and return a fractal image"""
#     image = np.zeros((Ny, Nx), dtype=float)
#     dx = (xmax - xmin) * 1. / Nx
#     dy = (ymax - ymin) * 1. / Ny
#
#     for x in range(Nx):
#         rpart = xmin + x * dx
#         for y in range(Ny):
#             ipart = ymin + y * dy
#             color = mandel(rpart, ipart, max_iter)
#             image[y, x] = color
#     return image

# %%
print "Bare Cython:"
# %timeit create_fractal(300, 200, -2, 1, -1, 1, 20)
# Out:
# Bare Cython:
# 1 loops, best of 3: 254 ms per loop

# %%
# %%cython
# #%matplotlib inline
# import numpy as np
# import matplotlib.pyplot as plt
#
#
# cdef mandel(x, y, max_iter):
#     """
#     Given z = x + iy and max_iter, determine whether the candidate
#     is in the mandelbrot set for the given number of iterations
#     """
#     cdef int i
#     cdef complex c = complex(x, y)
#     cdef complex z = 0.0j
#     for i in range(max_iter):
#         z = z*z + c
#         if (z.real*z.real + z.imag*z.imag) >= 4:
#             return i
#
#     return max_iter
#
# def create_fractal(Nx, Ny, xmin, xmax, ymin, ymax, max_iter):
#     """Create and return a fractal image"""
#     cdef double[:,:] image = np.zeros((Ny, Nx), dtype=float)
#     cdef float dx = (xmax - xmin) * 1. / Nx
#     cdef float dy = (ymax - ymin) * 1. / Ny
#     cdef int x
#     cdef int y
#     cdef int color
#     cdef float rpart
#     cdef float ipart
#     for x in range(Nx):
#         rpart = xmin + x * dx
#
#         for y in range(Ny):
#             ipart = ymin + y * dy
#             color = mandel(rpart, ipart, max_iter)
#             image[y, x] = color
#     return image

# %%
print "Typed Cython:"
# %timeit create_fractal(300, 200, -2, 1, -1, 1, 20)
# Out:
# Typed Cython:
# 10 loops, best of 3: 20.6 ms per loop

# %%
# %%file mandelbrot.pyx
# import numpy as np
# import matplotlib.pyplot as plt
#
#
# cdef mandel(x, y, max_iter):
#     """
#     Given z = x + iy and max_iter, determine whether the candidate
#     is in the mandelbrot set for the given number of iterations
#     """
#     cdef int i
#     cdef complex c = complex(x, y)
#     cdef complex z = 0.0j
#     for i in range(max_iter):
#         z = z*z + c
#         if (z.real*z.real + z.imag*z.imag) >= 4:
#             return i
#
#     return max_iter
#
# def create_fractal(Nx, Ny, xmin, xmax, ymin, ymax, max_iter):
#     """Create and return a fractal image"""
#     cdef double[:,:] image = np.zeros((Ny, Nx), dtype=float)
#     cdef float dx = (xmax - xmin) * 1. / Nx
#     cdef float dy = (ymax - ymin) * 1. / Ny
#     cdef int x
#     cdef int y
#     cdef int color
#     cdef float rpart
#     cdef float ipart
#     for x in range(Nx):
#         rpart = xmin + x * dx
#
#         for y in range(Ny):
#             ipart = ymin + y * dy
#             color = mandel(rpart, ipart, max_iter)
#             image[y, x] = color
#     return image
# Out:
# Writing mandelbrot.pyx

# %%
# !cython -a mandelbrot.pyx

# %% [markdown]
# I can't actually check this because I get a gcc compile error on my machine (I'm using wakari).

# %% [markdown]
# ### Part 2: Numba

# %%
from numba import autojit

@autojit
def mandel(x, y, max_iter):
    """
    Given z = x + iy and max_iter, determine whether the candidate
    is in the mandelbrot set for the given number of iterations
    """
    c = complex(x, y)
    z = 0.0j
    for i in range(max_iter):
        z = z*z + c
        if (z.real*z.real + z.imag*z.imag) >= 4:
            return i

    return max_iter

@autojit
def create_fractal(Nx, Ny, xmin, xmax, ymin, ymax, max_iter):
    """Create and return a fractal image"""
    image = np.zeros((Ny, Nx), dtype=float)
    dx = (xmax - xmin) * 1. / Nx
    dy = (ymax - ymin) * 1. / Ny
    
    for x in range(Nx):
        rpart = xmin + x * dx
        for y in range(Ny):
            ipart = ymin + y * dy
            color = mandel(rpart, ipart, max_iter)
            image[y, x] = color
    return image

# %%
print "Numba:"
# %timeit create_fractal(300, 200, -2, 1, -1, 1, 20)
# Out:
# Numba:
# 1 loops, best of 3: 3.49 ms per loop

# %% [markdown]
# ### Part 3

# %% [markdown]
# (timeits are under each case above)
#
# Summary:
#
# Python Only: 401ms
#
# Bare Cython: 253ms
#
# Typed Cython: 20.7ms
#
# Numba: 3.5ms!

# %% [markdown]
# ### Part 4

# %%
image = create_fractal(700, 500, -2,2,-2,2, 256)

plt.imshow(np.log10(image.T), cmap=plt.cm.Set3,interpolation='nearest')
plt.xticks([])
plt.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)
